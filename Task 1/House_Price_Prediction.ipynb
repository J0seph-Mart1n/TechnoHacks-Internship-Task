# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("kc_house_data.csv")

# %%
data = data.drop(['date'],axis=1)

# %%
data
# Out:
#                id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520  221900.0         3       1.00         1180      5650
# 1      6414100192  538000.0         3       2.25         2570      7242
# 2      5631500400  180000.0         2       1.00          770     10000
# 3      2487200875  604000.0         4       3.00         1960      5000
# 4      1954400510  510000.0         3       2.00         1680      8080
# ...           ...       ...       ...        ...          ...       ...
# 21608   263000018  360000.0         3       2.50         1530      1131
# 21609  6600060120  400000.0         4       2.50         2310      5813
# 21610  1523300141  402101.0         2       0.75         1020      1350
# 21611   291310100  400000.0         3       2.50         1600      2388
# 21612  1523300157  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   price          21613 non-null  float64
#  2   bedrooms       21613 non-null  int64
#  3   bathrooms      21613 non-null  float64
#  4   sqft_living    21613 non-null  int64
#  5   sqft_lot       21613 non-null  int64
#  6   floors         21613 non-null  float64
#  7   waterfront     21613 non-null  int64
#  8   view           21613 non-null  int64
#  9   condition      21613 non-null  int64
#  10  grade          21613 non-null  int64
#  11  sqft_above     21613 non-null  int64
#  12  sqft_basement  21613 non-null  int64
#  13  yr_built       21613 non-null  int64
#  14  yr_renovated   21613 non-null  int64
#  15  zipcode        21613 non-null  int64
#  16  lat            21613 non-null  float64
# ...

# %%
from sklearn.model_selection import train_test_split

X = data.drop(["price"],axis=1)
Y = data['price']

# %%
X
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      7129300520         3       1.00         1180      5650     1.0
# 1      6414100192         3       2.25         2570      7242     2.0
# 2      5631500400         2       1.00          770     10000     1.0
# 3      2487200875         4       3.00         1960      5000     1.0
# 4      1954400510         3       2.00         1680      8080     1.0
# ...           ...       ...        ...          ...       ...     ...
# 21608   263000018         3       2.50         1530      1131     3.0
# 21609  6600060120         4       2.50         2310      5813     2.0
# 21610  1523300141         2       0.75         1020      1350     2.0
# 21611   291310100         3       2.50         1600      2388     2.0
# 21612  1523300157         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
Y
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
X_test, X_train, Y_test, Y_train = train_test_split(X, Y, test_size=0.2)

# %%
train_data = X_train.join(Y_train)

# %%
train_data = train_data.drop(['date'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[186], line 1
# ----> 1 train_data = train_data.drop(['date'], axis=1)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
# ...

# %%
train_data
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 2330   7454000030         2       1.00          740      6840     1.0
# 18029  2558640110         4       2.75         2270      7375     1.0
# 8698   3797000745         3       1.00         1370      3500     1.5
# 13554  1023059186         3       1.00         1530      9465     1.0
# 2115    251200240         4       2.75         2100      7236     1.0
# ...           ...       ...        ...          ...       ...     ...
# 942      65000400         4       3.00         1490      6766     1.5
# 16783  2767604254         2       2.50         1140      1182     3.0
# 1291   3365900465         3       1.50         1370     10176     1.0
# 15061  2597300020         5       2.50         3780     20000     1.0
# 14276  1442700360         3       2.25         2600     15000     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
train_data.hist(figsize=(10, 15))
# Out:
# array([[<Axes: title={'center': 'id'}>,
#         <Axes: title={'center': 'bedrooms'}>,
#         <Axes: title={'center': 'bathrooms'}>,
#         <Axes: title={'center': 'sqft_living'}>],
#        [<Axes: title={'center': 'sqft_lot'}>,
#         <Axes: title={'center': 'floors'}>,
#         <Axes: title={'center': 'waterfront'}>,
#         <Axes: title={'center': 'view'}>],
#        [<Axes: title={'center': 'condition'}>,
#         <Axes: title={'center': 'grade'}>,
#         <Axes: title={'center': 'sqft_above'}>,
#         <Axes: title={'center': 'sqft_basement'}>],
#        [<Axes: title={'center': 'yr_built'}>,
#         <Axes: title={'center': 'yr_renovated'}>,
#         <Axes: title={'center': 'zipcode'}>,
#         <Axes: title={'center': 'lat'}>],
#        [<Axes: title={'center': 'long'}>,
#         <Axes: title={'center': 'sqft_living15'}>,
#         <Axes: title={'center': 'sqft_lot15'}>,
#         <Axes: title={'center': 'price'}>]], dtype=object)

# %%
'''train_data['sqft_living'] = np.log(train_data['sqft_living']+1)
train_data['sqft_lot'] = np.log(train_data['sqft_lot']+1)
train_data['sqft_above'] = np.log(train_data['sqft_above']+1)
train_data['sqft_basement'] = np.log(train_data['sqft_basement']+1)
train_data['price'] = np.log(train_data['price']+1)'''

# %%
train_data.hist(figsize=(10, 15))
# Out:
# array([[<Axes: title={'center': 'id'}>,
#         <Axes: title={'center': 'bedrooms'}>,
#         <Axes: title={'center': 'bathrooms'}>,
#         <Axes: title={'center': 'sqft_living'}>],
#        [<Axes: title={'center': 'sqft_lot'}>,
#         <Axes: title={'center': 'floors'}>,
#         <Axes: title={'center': 'waterfront'}>,
#         <Axes: title={'center': 'view'}>],
#        [<Axes: title={'center': 'condition'}>,
#         <Axes: title={'center': 'grade'}>,
#         <Axes: title={'center': 'sqft_above'}>,
#         <Axes: title={'center': 'sqft_basement'}>],
#        [<Axes: title={'center': 'yr_built'}>,
#         <Axes: title={'center': 'yr_renovated'}>,
#         <Axes: title={'center': 'zipcode'}>,
#         <Axes: title={'center': 'lat'}>],
#        [<Axes: title={'center': 'long'}>,
#         <Axes: title={'center': 'sqft_living15'}>,
#         <Axes: title={'center': 'sqft_lot15'}>,
#         <Axes: title={'center': 'price'}>]], dtype=object)

# %%
train_data
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 2330   7454000030         2       1.00          740      6840     1.0
# 18029  2558640110         4       2.75         2270      7375     1.0
# 8698   3797000745         3       1.00         1370      3500     1.5
# 13554  1023059186         3       1.00         1530      9465     1.0
# 2115    251200240         4       2.75         2100      7236     1.0
# ...           ...       ...        ...          ...       ...     ...
# 942      65000400         4       3.00         1490      6766     1.5
# 16783  2767604254         2       2.50         1140      1182     3.0
# 1291   3365900465         3       1.50         1370     10176     1.0
# 15061  2597300020         5       2.50         3780     20000     1.0
# 14276  1442700360         3       2.25         2600     15000     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
plt.figure(figsize=(25,15))
sns.heatmap(train_data.corr(), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %%
train_data.hist(figsize=(10, 15))
# Out:
# array([[<Axes: title={'center': 'id'}>,
#         <Axes: title={'center': 'bedrooms'}>,
#         <Axes: title={'center': 'bathrooms'}>,
#         <Axes: title={'center': 'sqft_living'}>],
#        [<Axes: title={'center': 'sqft_lot'}>,
#         <Axes: title={'center': 'floors'}>,
#         <Axes: title={'center': 'waterfront'}>,
#         <Axes: title={'center': 'view'}>],
#        [<Axes: title={'center': 'condition'}>,
#         <Axes: title={'center': 'grade'}>,
#         <Axes: title={'center': 'sqft_above'}>,
#         <Axes: title={'center': 'sqft_basement'}>],
#        [<Axes: title={'center': 'yr_built'}>,
#         <Axes: title={'center': 'yr_renovated'}>,
#         <Axes: title={'center': 'zipcode'}>,
#         <Axes: title={'center': 'lat'}>],
#        [<Axes: title={'center': 'long'}>,
#         <Axes: title={'center': 'sqft_living15'}>,
#         <Axes: title={'center': 'sqft_lot15'}>,
#         <Axes: title={'center': 'price'}>]], dtype=object)

# %%
train_data.bedrooms.value_counts()
# Out:
# bedrooms
# 3     1998
# 4     1353
# 2      535
# 5      331
# 6       50
# 1       37
# 7       10
# 0        3
# 8        3
# 9        2
# 10       1
# Name: count, dtype: int64

# %%
train_data
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 2330   7454000030         2       1.00          740      6840     1.0
# 18029  2558640110         4       2.75         2270      7375     1.0
# 8698   3797000745         3       1.00         1370      3500     1.5
# 13554  1023059186         3       1.00         1530      9465     1.0
# 2115    251200240         4       2.75         2100      7236     1.0
# ...           ...       ...        ...          ...       ...     ...
# 942      65000400         4       3.00         1490      6766     1.5
# 16783  2767604254         2       2.50         1140      1182     3.0
# 1291   3365900465         3       1.50         1370     10176     1.0
# 15061  2597300020         5       2.50         3780     20000     1.0
# 14276  1442700360         3       2.25         2600     15000     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
train_data = train_data.join(pd.get_dummies(train_data.floors)).drop(['floors'], axis=1)

# %%
plt.figure(figsize=(25,15))
sns.heatmap(train_data.corr(), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(25,15))
sns.scatterplot(x='lat',y='long', data=train_data, hue='price', palette='cool')
# Out:
# <Axes: xlabel='lat', ylabel='long'>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler


X_train, Y_train = train_data.drop(['price'], axis=1), train_data['price']
X_train = X_train.drop(['id'],axis=1)
X_train = X_train.drop([1.0], axis=1)
X_train = X_train.drop([1.5], axis = 1)
X_train = X_train.drop([2.0], axis = 1)
X_train = X_train.drop([2.5], axis = 1)
X_train = X_train.drop([3.0], axis = 1)
X_train = X_train.drop([3.5], axis = 1)


reg = LinearRegression()
reg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
test_data = X_test.join(Y_test)

'''test_data['sqft_living'] = np.log(test_data['sqft_living']+1)
test_data['sqft_lot'] = np.log(test_data['sqft_lot']+1)
test_data['sqft_above'] = np.log(test_data['sqft_above']+1)
test_data['sqft_basement'] = np.log(test_data['sqft_basement']+1)
test_data['price'] = np.log(test_data['price']+1)'''

test_data = test_data.join(pd.get_dummies(test_data.floors)).drop(['floors'], axis=1)
test_data = test_data.drop(['date'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[199], line 10
#       3 '''test_data['sqft_living'] = np.log(test_data['sqft_living']+1)
#       4 test_data['sqft_lot'] = np.log(test_data['sqft_lot']+1)
#       5 test_data['sqft_above'] = np.log(test_data['sqft_above']+1)
#       6 test_data['sqft_basement'] = np.log(test_data['sqft_basement']+1)
#       7 test_data['price'] = np.log(test_data['price']+1)'''
#       9 test_data = test_data.join(pd.get_dummies(test_data.floors)).drop(['floors'], axis=1)
# ---> 10 test_data = test_data.drop(['date'], axis=1)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
# ...

# %%
X_test, Y_test = test_data.drop(['price'], axis=1), test_data['price']
X_test = X_test.drop(['id'],axis=1)
X_test = X_test.drop([1.0],axis=1)
X_test=X_test.drop([1.5],axis=1)
X_test=X_test.drop([2.0],axis=1)
X_test=X_test.drop([2.5],axis=1)
X_test=X_test.drop([3.0],axis=1)
X_test=X_test.drop([3.5],axis=1)

# %%
X_train
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  waterfront  view  \
# 2330          2       1.00          740      6840           0     0
# 18029         4       2.75         2270      7375           0     0
# 8698          3       1.00         1370      3500           0     0
# 13554         3       1.00         1530      9465           0     0
# 2115          4       2.75         2100      7236           0     0
# ...         ...        ...          ...       ...         ...   ...
# 942           4       3.00         1490      6766           0     1
# 16783         2       2.50         1140      1182           0     0
# 1291          3       1.50         1370     10176           0     0
# 15061         5       2.50         3780     20000           0     1
# 14276         3       2.25         2600     15000           0     0
#
#        condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# ...

# %%
reg.score(X_test,Y_test)
# Out:
# 0.6981592314514201

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()
forest.fit(X_train,Y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test,Y_test)
# Out:
# 0.8584130914743466

# %%
from sklearn.model_selection import GridSearchCV

forest = RandomForestRegressor()

param_grid = {
    'n_estimators':[100,200,300],
    'min_samples_split':[2,4],
    'max_depth':[None,4,8]
}

grid_search = GridSearchCV(forest, param_grid, cv=5,
                          scoring='neg_mean_squared_error',
                          return_train_score=True)

grid_search.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [None, 4, 8], 'min_samples_split': [2, 4],
#                          'n_estimators': [100, 200, 300]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor()

# %%
grid_search.best_estimator_.score(X_train,Y_train)
# Out:
# 0.972427731830135
